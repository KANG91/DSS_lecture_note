# %%
import seaborn as sns

# %%
tips_raw = sns.load_dataset("tips")

# %%
tips_raw.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips_raw["total_bill"].tail()
# Out:
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, dtype: float64

# %%
tips_raw["tip"].tail()
# Out:
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, dtype: float64

# %%
tips_raw.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
column = ["total_bill", "tip", "sex", "smoker", "day", "time", "size"]
df = pd.DataFrame(columns = column)
df["total_bill"] = [16.99]
# Out:
#    total_bill  tip  sex smoker  day time size
# 0       16.99  NaN  NaN    NaN  NaN  NaN  NaN

# %%
column = ["total_bill", "tip", "sex", "smoker", "day", "time", "size"]
total_bill = [16.99]
df2 = pd.DataFrame({"total_bill" : total_bill}, columns = column)
df2
# Out:
#    total_bill  tip  sex smoker  day time size
# 0       16.99  NaN  NaN    NaN  NaN  NaN  NaN

# %%
tips = tips_raw.copy()

# %%
tips[:100].groupby(["sex"]).size().reset_index(name = "counts")
# Out:
#       sex  counts
# 0    Male      74
# 1  Female      26

# %%
tips[:100]
# Out:
#     total_bill   tip     sex smoker   day    time  size
# 0        16.99  1.01  Female     No   Sun  Dinner     2
# 1        10.34  1.66    Male     No   Sun  Dinner     3
# 2        21.01  3.50    Male     No   Sun  Dinner     3
# 3        23.68  3.31    Male     No   Sun  Dinner     2
# 4        24.59  3.61  Female     No   Sun  Dinner     4
# 5        25.29  4.71    Male     No   Sun  Dinner     4
# 6         8.77  2.00    Male     No   Sun  Dinner     2
# 7        26.88  3.12    Male     No   Sun  Dinner     4
# 8        15.04  1.96    Male     No   Sun  Dinner     2
# 9        14.78  3.23    Male     No   Sun  Dinner     2
# 10       10.27  1.71    Male     No   Sun  Dinner     2
# 11       35.26  5.00  Female     No   Sun  Dinner     4
# 12       15.42  1.57    Male     No   Sun  Dinner     2
# 13       18.43  3.00    Male     No   Sun  Dinner     4
# 14       14.83  3.02  Female     No   Sun  Dinner     2
# 15       21.58  3.92    Male     No   Sun  Dinner     2
# ...

# %%
female = tips["sex"] == "Female"
tips[female].reset_index()
# Out:
#     index  total_bill   tip     sex smoker   day    time  size
# 0       0       16.99  1.01  Female     No   Sun  Dinner     2
# 1       4       24.59  3.61  Female     No   Sun  Dinner     4
# 2      11       35.26  5.00  Female     No   Sun  Dinner     4
# 3      14       14.83  3.02  Female     No   Sun  Dinner     2
# 4      16       10.33  1.67  Female     No   Sun  Dinner     3
# 5      18       16.97  3.50  Female     No   Sun  Dinner     3
# 6      21       20.29  2.75  Female     No   Sat  Dinner     2
# 7      22       15.77  2.23  Female     No   Sat  Dinner     2
# 8      29       19.65  3.00  Female     No   Sat  Dinner     2
# 9      32       15.06  3.00  Female     No   Sat  Dinner     2
# 10     33       20.69  2.45  Female     No   Sat  Dinner     4
# 11     37       16.93  3.07  Female     No   Sat  Dinner     3
# 12     51       10.29  2.60  Female     No   Sun  Dinner     2
# 13     52       34.81  5.20  Female     No   Sun  Dinner     4
# ...
