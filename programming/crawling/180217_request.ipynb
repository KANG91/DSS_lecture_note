# %%
import requests
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup

# %%
url = "http://www.naver.com"
html = urlopen(url).read()

# %%
dom = BeautifulSoup(requests.get("http://www.naver.com").text, "lxml")
dom
# Out:
# <!DOCTYPE html>
# <html class="svgless" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="origin" name="Referrer"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1100" name="viewport"/>
# <meta content="NAVER" name="apple-mobile-web-app-title"/>
# <meta content="index,nofollow" name="robots"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"/>
# <meta content="네이버" property="og:title"/>
# <meta content="http://www.naver.com/" property="og:url"/>
# <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="http://www.naver.com/" name="twitter:url"/>
# ...

# %%
keywords = dom.select(".ah_roll .ah_item")
keywords
# Out:
# [<li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">1</span>
#  <span class="ah_k">예학영</span>
#  </a>
#  </li>, <li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">2</span>
#  <span class="ah_k">설인아</span>
#  </a>
#  </li>, <li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">3</span>
#  <span class="ah_k">로또794회 당첨번호</span>
#  </a>
#  </li>, <li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">4</span>
#  <span class="ah_k">김아랑</span>
#  </a>
#  </li>, <li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">5</span>
#  <span class="ah_k">장우혁</span>
#  </a>
#  </li>, <li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">6</span>
#  <span class="ah_k">레데츠카</span>
#  </a>
#  </li>, <li class="ah_item">
# ...

# %%
keywords = dom.select(".ah_roll .ah_l .ah_item")
keywords
# Out:
# [<li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">1</span>
#  <span class="ah_k">김아랑</span>
#  </a>
#  </li>, <li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">2</span>
#  <span class="ah_k">킴부탱</span>
#  </a>
#  </li>, <li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">3</span>
#  <span class="ah_k">조해리</span>
#  </a>
#  </li>, <li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">4</span>
#  <span class="ah_k">심석희</span>
#  </a>
#  </li>, <li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">5</span>
#  <span class="ah_k">진선유</span>
#  </a>
#  </li>, <li class="ah_item">
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">6</span>
#  <span class="ah_k">황대헌</span>
#  </a>
#  </li>, <li class="ah_item">
# ...

# %%
import pandas as pd
df = pd.DataFrame(columns = ["rank", "keyword"])
df
# Out:
# Empty DataFrame
# Columns: [rank, keyword]
# Index: []

# %%
for keyword in keywords : 
    df.loc[len(df)] = {
        "rank" : keyword.select_one(".ah_r").text,
        "keyword" : keyword.select_one(".ah_k").text,
    }

# %%
df_daum = pd.DataFrame(columns = ["rank", "keyword"])
response = requests.get("http://daum.net")
dom = BeautifulSoup(response.content, "html.parser")

# %%
daum_keywords = dom.select("#daumContent ol.list_hotissue.issue_row.list_mini > li")

# %%
for keyword in daum_keywords : 
    print(keyword.select_one(".ir_wa").text)
    print(keyword.select_one(".link_issue").text)
# Out:
# 1위
# 서이라
# 2위
# 예학영
# 3위
# 강타
# 4위
# 김아랑
# 5위
# 장우혁
# 6위
# 공조
# 7위
# 토토가 3
# 8위
# 문희준
# 9위
# 로맨스 패키지
# 10위
# 포항 지진
